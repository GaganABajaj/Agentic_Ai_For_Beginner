# %%
# !pip install -q \
langchain==0.3.14 \
langchain-openai==0.2.14 \
langchain-community==0.3.14 \
openai==1.59.6 \
python-dotenv==1.0.1 \
requests==2.32.3 \
beautifulsoup4==4.12.3 \
wikipedia==1.4.0 \
ipykernel==6.29.5 \
tavily-python==0.5.0
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 16.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 62.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.8/454.8 kB 33.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 kB 11.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 kB 9.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.5/438.5 kB 32.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 326.9/326.9 kB 25.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 94.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 4.3 MB/s eta 0:00:00
#   Building wheel for wikipedia (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipykernel==6.17.1, but you have ipykernel 6.29.5 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.3 which is incompatible.
# google-adk 2.4.0 requires requests<3,>=2.32.4, but you have requests 2.32.3 which is incompatible.
# libpysal 4.14.1 requires beautifulsoup4>=4.13.0, but you have beautifulsoup4 4.12.3 which is incompatible.
# langgraph-prebuilt 1.1.0 requires langchain-core>=1.3.1, but you have langchain-core 0.3.63 which is incompatible.
# langgraph-sdk 0.4.2 requires langchain-core<2,>=1.4.0, but you have langchain-core 0.3.63 which is incompatible.
# langgraph 1.2.9 requires langchain-core<2,>=1.4.7, but you have langchain-core 0.3.63 which is incompatible.

# %%
import os
os.kill(os.getpid(), 9)

# %%
#Langchain
from langchain.tools import Tool
from langchain_community.tools import DuckDuckGoSearchRun
from langchain.prompts import PromptTemplate
from langchain.chat_models import ChatOpenAI
from langchain.chains import LLMChain
from langchain.agents import initialize_agent, AgentType

# %%
import requests
from bs4 import BeautifulSoup

# %%
from dotenv import load_dotenv
from openai import OpenAI

# Load environment variables (e.g., OpenAI API keys) from a .env file located on the local system
env_path = r'E:\YTReusable\.env'
load_dotenv(env_path)
# Out:
# False

# %%
from google.colab import userdata
import os

os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')
os.environ["TAVILY_API_KEY"] = userdata.get("TAVILY_API_KEY")

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#prompt templates
from langchain.prompts import PromptTemplate

# Define a simple prompt template
prompt_template = PromptTemplate(
    input_variables=["name"],
    template="Hello, {name}! How can I help you today?"
)

# Generate the prompt by filling in the variable
formatted_prompt = prompt_template.format(name="David")
print(formatted_prompt)  # Output: Hello, John! How can I help you today?
# Out:
# Hello, David! How can I help you today?

# %%
#Working with chat openai
from langchain.chat_models import ChatOpenAI

# Initialize the OpenAI Chat model
# chat_model = ChatOpenAI(model="gpt-3.5-turbo")
chat_model = ChatOpenAI(model="gpt-5.4-mini")

# Send a message to the model and get the response
response = chat_model.invoke("What is Capital of USA?")
print(response)  # Output: The capital of the United States of America is Washington, D.C
# Out:
# content='The capital of the USA is **Washington, D.C.**' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 12, 'total_tokens': 28, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-5.4-mini', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None} id='run--79c53623-2637-4cfd-b8b1-290b420f469b-0'

# %%
#LLM Chains
from langchain.chat_models import ChatOpenAI
from langchain import PromptTemplate
from langchain.chains import LLMChain

# llm = ChatOpenAI(model_name='gpt-3.5-turbo-1106')
llm = ChatOpenAI(model="gpt-5.4-mini")

learn_template = """
I want you to act as a consultant for a AI training
Return a list of topics and why it is important to learn in given area of AI
The description should be relevant to recent advancement in AI
What are some good topics to learn in {AI_topic}
"""

prompt_template = PromptTemplate(
    input_variables=["AI_topic"],
    template=learn_template,
)

description = "Please suggest me topics to learn in Deep learning"

prompt_template.format(AI_topic=description)

chain = LLMChain(llm=llm, prompt=prompt_template)

print(chain.run(description))
# Out:
# Absolutely — here’s a practical list of **deep learning topics to learn**, along with **why each matters**, especially in light of **recent AI advancements** like LLMs, multimodal models, diffusion models, and AI agents.
#
# ## Recommended Deep Learning Topics
#
# ### 1. Neural Network Fundamentals
# **Why it matters:**
# This is the foundation of deep learning. You need to understand neurons, layers, activations, loss functions, and backpropagation before moving to advanced models.
#
# **Recent relevance:**
# Even modern models like transformers still rely on these core ideas.
#
# ---
#
# ### 2. Optimization Algorithms
# **Why it matters:**
# Training deep models depends on good optimization. Learn gradient descent, SGD, Adam, learning rate schedules, momentum, and weight decay.
#
# **Recent relevance:**
# Large models are expensive to train, so optimization techniques strongly affect performance and stability.
#
# ---
#
# ### 3. Regularization Techniques
# **Why it matters:**
# These help prevent overfitting. Learn dropout, batch normalization, early stopping, data augmentation, and label smoothing.
#
# **Recent relevance:**
# As models get larger, controlling generalization becomes more important.
#
# ---
#
# ### 4. Convolutional Neural Networks (CNNs)
# **Why it matters:**
# CNNs are essential for image-related tasks such as classification, detection, and segmentation.
#
# **Recent relevance:**
# Although vision transformers are popular, CNN concepts still matter and are widely used in computer vision pipelines.
#
# ---
#
# ### 5. Recurrent Neural Networks (RNNs), LSTMs, and GRUs
# **Why it matters:**
# These were the classic methods for sequence data like text and time series.
#
# **Recent relevance:**
# They are less dominant now, but understanding them helps you appreciate why transformers replaced them for many NLP tasks.
#
# ---
#
# ### 6. Transformers
# **Why it matters:**
# This is one of the most important topics in modern AI. Transformers power models like ChatGPT, GPT, BERT, Claude, and many others.
#
# **Recent relevance:**
# They are the core architecture behind recent breakthroughs in language, vision, audio, and multimodal AI.
#
# ---
#
# ### 7. Attention Mechanisms
# **Why it matters:**
# Attention allows models to focus on the most relevant parts of input data.
#
# **Recent relevance:**
# This is the key idea behind transformers and many state-of-the-art models.
#
# ---
#
# ### 8. Natural Language Processing with Deep Learning
# **Why it matters:**
# Learn tokenization, embeddings, language modeling, text classification, summarization, translation, and question answering.
#
# **Recent relevance:**
# LLMs have made NLP one of the fastest-growing areas in AI.
#
# ---
#
# ### 9. Large Language Models (LLMs)
# **Why it matters:**
# LLMs are now central to modern AI applications. Learn pretraining, fine-tuning, prompting, instruction tuning, and RLHF.
#
# **Recent relevance:**
# This is one of the most important areas in current AI research and industry.
#
# ---
#
# ### 10. Transfer Learning and Fine-Tuning
# **Why it matters:**
# Instead of training from scratch, you can adapt pretrained models to your own task.
#
# **Recent relevance:**
# This is the standard approach for many real-world AI applications today.
#
# ---
#
# ### 11. Embeddings and Representation Learning
# **Why it matters:**
# Embeddings convert text, images, and other data into useful vector representations.
#
# **Recent relevance:**
# They are used in search, recommendation systems, retrieval-augmented generation (RAG), and semantic similarity.
#
# ---
#
# ### 12. Retrieval-Augmented Generation (RAG)
# **Why it matters:**
# RAG combines search/retrieval with LLMs to improve factual accuracy and use private or updated data.
#
# **Recent relevance:**
# This is one of the most practical and widely used techniques in enterprise AI applications.
#
# ---
#
# ### 13. Generative Models
# **Why it matters:**
# Learn how AI generates new content such as text, images, audio, and video.
#
# **Recent relevance:**
# Modern generative AI is driving major progress in content creation and creative tools.
#
# ---
#
# ### 14. Diffusion Models
# **Why it matters:**
# These are the main models behind high-quality image generation.
#
# **Recent relevance:**
# They power systems like Stable Diffusion and many text-to-image and text-to-video tools.
#
# ---
#
# ### 15. Multimodal Learning
# **Why it matters:**
# This area combines text, image, audio, and video in one model.
#
# **Recent relevance:**
# Recent AI systems increasingly support multimodal input and output, making this a key future skill.
#
# ---
#
# ### 16. Computer Vision
# **Why it matters:**
# Learn image classification, object detection, segmentation, and keypoint detection.
#
# **Recent relevance:**
# Computer vision is now integrated with transformers and multimodal models, expanding its applications.
#
# ---
#
# ### 17. Model Evaluation and Metrics
# **Why it matters:**
# You need to know how to measure performance correctly using accuracy, precision, recall, F1, BLEU, ROUGE, perplexity, and others.
#
# **Recent relevance:**
# Evaluating LLMs and generative models is more complex than traditional ML.
#
# ---
#
# ### 18. Explainability and Interpretability
# **Why it matters:**
# Helps you understand why a model makes certain predictions.
#
# **Recent relevance:**
# As AI is used in sensitive areas, interpretability is important for trust, debugging, and compliance.
#
# ---
#
# ### 19. AI Safety and Alignment Basics
# **Why it matters:**
# Learn about hallucinations, bias, robustness, prompt injection, and safe deployment.
#
# **Recent relevance:**
# With powerful LLMs and agents, AI safety has become a major concern.
#
# ---
#
# ### 20. Deployment and MLOps for Deep Learning
# **Why it matters:**
# You should know how to deploy models efficiently using APIs, containers, model serving, monitoring, and scaling.
#
# **Recent relevance:**
# Real-world AI success depends not just on model quality, but on reliable deployment and maintenance.
#
# ---
#
# ## Best Learning Order
# If you are starting deep learning, a good path is:
#
# 1. Python + NumPy basics
# 2. Neural network fundamentals
# 3. Optimization and regularization
# 4. CNNs and sequence models
# 5. Transformers and attention
# 6. NLP and LLMs
# 7. RAG and embeddings
# 8. Multimodal and diffusion models
# 9. Deployment, evaluation, and AI safety
#
# ---
#
# ## Suggested Focus Areas for Modern AI Careers
# If your goal is to work in current AI industry, prioritize:
#
# - **Transformers**
# - **LLMs**
# - **RAG**
# - **Embeddings**
# - **Fine-tuning**
# - **Multimodal AI**
# - **Diffusion models**
# - **AI deployment/MLOps**
#
# ---
#
# If you want, I can also turn this into:
# 1. a **beginner-friendly learning roadmap**,
# 2. a **3-month deep learning study plan**, or
# 3. a **topic list with free resources and project ideas**.

# %%
# !pip install -U duckduckgo-search

# %%
from langchain.agents import initialize_agent, AgentType
from langchain.chat_models import ChatOpenAI
from langchain.tools import Tool
from langchain_community.tools import DuckDuckGoSearchRun

# Install the missing package


# Define a simple tool
def my_tool_function(query: str) -> str:
    return f"Tool response: {query}"

#creating tool from function
my_tool = Tool.from_function(func=my_tool_function, name="simple_tool", description="A simple tool")
ddg_search = DuckDuckGoSearchRun()



# Initialize the LLM and the agent
# llm = ChatOpenAI(model="gpt-3.5-turbo")
llm = ChatOpenAI(model="gpt-5.4-mini")

tools = [ddg_search,my_tool]

# Create an agent
agent = initialize_agent(tools, llm, agent_type=AgentType.ZERO_SHOT_REACT_DESCRIPTION, verbose=True)

# Use the agent
response = agent.run("What's the weather like today in London?")
print(response)  # Output: The agent will choose to use the tool or model to respond based on context
# Out:
# Requirement already satisfied: duckduckgo-search in /usr/local/lib/python3.12/dist-packages (8.1.1)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from duckduckgo-search) (8.4.2)
# Requirement already satisfied: primp>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from duckduckgo-search) (1.3.1)
# Requirement already satisfied: lxml>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from duckduckgo-search) (6.1.1)
#
#
# > Entering new AgentExecutor chain...
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# /tmp/ipykernel_3257/2924846409.py in <cell line: 0>()
#      27
#      28 # Use the agent
# ---> 29 response = agent.run("What's the weather like today in London?")
#      30 print(response)  # Output: The agent will choose to use the tool or model to respond based on context
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     189                 warned = True
#     190                 emit_warning()
# --> 191             return wrapped(*args, **kwargs)
#     192
#     193         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.12/dist-packages/langchain/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     604             if len(args) != 1:
#     605                 raise ValueError("`run` supports only one positional argument.")
# --> 606             return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     607                 _output_key
#     608             ]
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     189                 warned = True
#     190                 emit_warning()
# --> 191             return wrapped(*args, **kwargs)
#     192
#     193         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.12/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     387         }
#     388
# --> 389         return self.invoke(
#     390             inputs,
#     391             cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#
# /usr/local/lib/python3.12/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     168         except BaseException as e:
#     169             run_manager.on_chain_error(e)
# --> 170             raise e
#     171         run_manager.on_chain_end(outputs)
#     172
#
# /usr/local/lib/python3.12/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     158             self._validate_inputs(inputs)
#     159             outputs = (
# --> 160                 self._call(inputs, run_manager=run_manager)
#     161                 if new_arg_supported
#     162                 else self._call(inputs)
#
# /usr/local/lib/python3.12/dist-packages/langchain/agents/agent.py in _call(self, inputs, run_manager)
#    1622         # We now enter the agent loop (until it returns something).
#    1623         while self._should_continue(iterations, time_elapsed):
# -> 1624             next_step_output = self._take_next_step(
#    1625                 name_to_tool_map,
#    1626                 color_mapping,
#
# /usr/local/lib/python3.12/dist-packages/langchain/agents/agent.py in _take_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1330             [
#    1331                 a
# -> 1332                 for a in self._iter_next_step(
#    1333                     name_to_tool_map,
#    1334                     color_mapping,
#
# /usr/local/lib/python3.12/dist-packages/langchain/agents/agent.py in _iter_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1356
#    1357             # Call the LLM to see what to do.
# -> 1358             output = self._action_agent.plan(
#    1359                 intermediate_steps,
#    1360                 callbacks=run_manager.get_child() if run_manager else None,
#
# /usr/local/lib/python3.12/dist-packages/langchain/agents/agent.py in plan(self, intermediate_steps, callbacks, **kwargs)
#     802         """
#     803         full_inputs = self.get_full_inputs(intermediate_steps, **kwargs)
# --> 804         full_output = self.llm_chain.predict(callbacks=callbacks, **full_inputs)
#     805         return self.output_parser.parse(full_output)
#     806
#
# /usr/local/lib/python3.12/dist-packages/langchain/chains/llm.py in predict(self, callbacks, **kwargs)
#     316                 completion = llm.predict(adjective="funny")
#     317         """
# --> 318         return self(kwargs, callbacks=callbacks)[self.output_key]
#     319
#     320     async def apredict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     189                 warned = True
#     190                 emit_warning()
# --> 191             return wrapped(*args, **kwargs)
#     192
#     193         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.12/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     387         }
#     388
# --> 389         return self.invoke(
#     390             inputs,
#     391             cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#
# /usr/local/lib/python3.12/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     168         except BaseException as e:
#     169             run_manager.on_chain_error(e)
# --> 170             raise e
#     171         run_manager.on_chain_end(outputs)
#     172
#
# /usr/local/lib/python3.12/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     158             self._validate_inputs(inputs)
#     159             outputs = (
# --> 160                 self._call(inputs, run_manager=run_manager)
#     161                 if new_arg_supported
#     162                 else self._call(inputs)
#
# /usr/local/lib/python3.12/dist-packages/langchain/chains/llm.py in _call(self, inputs, run_manager)
#     124         run_manager: Optional[CallbackManagerForChainRun] = None,
#     125     ) -> Dict[str, str]:
# --> 126         response = self.generate([inputs], run_manager=run_manager)
#     127         return self.create_outputs(response)[0]
#     128
#
# /usr/local/lib/python3.12/dist-packages/langchain/chains/llm.py in generate(self, input_list, run_manager)
#     136         callbacks = run_manager.get_child() if run_manager else None
#     137         if isinstance(self.llm, BaseLanguageModel):
# --> 138             return self.llm.generate_prompt(
#     139                 prompts,
#     140                 stop,
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     955     ) -> LLMResult:
#     956         prompt_messages = [p.to_messages() for p in prompts]
# --> 957         return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#     958
#     959     @override
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     774             try:
#     775                 results.append(
# --> 776                     self._generate_with_cache(
#     777                         m,
#     778                         stop=stop,
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in _generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1020             result = generate_from_stream(iter(chunks))
#    1021         elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1022             result = self._generate(
#    1023                 messages, stop=stop, run_manager=run_manager, **kwargs
#    1024             )
#
# /usr/local/lib/python3.12/dist-packages/langchain_community/chat_models/openai.py in _generate(self, messages, stop, run_manager, stream, **kwargs)
#     474             **kwargs,
#     475         }
# --> 476         response = self.completion_with_retry(
#     477             messages=message_dicts, run_manager=run_manager, **params
#     478         )
#
# /usr/local/lib/python3.12/dist-packages/langchain_community/chat_models/openai.py in completion_with_retry(self, run_manager, **kwargs)
#     385         """Use tenacity to retry the completion call."""
#     386         if is_openai_v1():
# --> 387             return self.client.create(**kwargs)
#     388
#     389         retry_decorator = _create_retry_decorator(self, run_manager=run_manager)
#
# /usr/local/lib/python3.12/dist-packages/openai/_utils/_utils.py in wrapper(*args, **kwargs)
#     277                         msg = f"Missing required argument: {quote(missing[0])}"
#     278                 raise TypeError(msg)
# --> 279             return func(*args, **kwargs)
#     280
#     281         return wrapper  # type: ignore
#
# /usr/local/lib/python3.12/dist-packages/openai/resources/chat/completions.py in create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     857     ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     858         validate_response_format(response_format)
# --> 859         return self._post(
#     860             "/chat/completions",
#     861             body=maybe_transform(
#
# /usr/local/lib/python3.12/dist-packages/openai/_base_client.py in post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1281             method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1282         )
# -> 1283         return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#    1284
#    1285     def patch(
#
# /usr/local/lib/python3.12/dist-packages/openai/_base_client.py in request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     958             retries_taken = 0
#     959
# --> 960         return self._request(
#     961             cast_to=cast_to,
#     962             options=options,
#
# /usr/local/lib/python3.12/dist-packages/openai/_base_client.py in _request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1062
#    1063             log.debug("Re-raising status error")
# -> 1064             raise self._make_status_error_from_response(err.response) from None
#    1065
#    1066         return self._process_response(
#
# BadRequestError: Error code: 400 - {'error': {'message': "Unsupported parameter: 'stop' is not supported with this model.", 'type': 'invalid_request_error', 'param': 'stop', 'code': 'unsupported_parameter'}}

# %%
prompt_template = "Summarize the following content: {content}"
llm = ChatOpenAI(model="gpt-3.5-turbo-16k")

llm_chain = LLMChain(
    llm=llm,
    prompt=PromptTemplate.from_template(prompt_template)
)

summarize_tool = Tool.from_function(
    func=llm_chain.run,
    name="Summarizer",
    description="Summarizes a web page"
)

# %%
tools = [ddg_search, summarize_tool]

agent = initialize_agent(
    tools=tools,
    agent_type=AgentType.ZERO_SHOT_REACT_DESCRIPTION,
    llm=llm,
    verbose=True,handle_parsing_errors=True
)

# %%
prompt = """Please tell me how to become a good footballer"""
print(agent.invoke(prompt))
# Out:
# > Entering new AgentExecutor chain...
# I should start by searching for tips and advice on becoming a good footballer.
# Action: duckduckgo_search
# Action Input: "tips for becoming a good footballer"
# Observation: To become a great footballer and dominate the world stage like Haaland or Mbappe, it takes years of hard work and an intensive routine. ... there are still some things that can be done to almost immediately boost your game as a football player. Here are our top 5 tips on how to get better at football that you can implement right away to see big ... In this 'MASTERCLASS'-video, footballer Oskar Jansson takes you through how to become a better football player with the most important things to consider whe... Whether you are a beginner or an advanced player, implementing the tips discussed in this article can help improve your overall skills and tactics on the field. Soccer training is essential to becoming a better player. By practicing every day and focusing on your first touch, ball control in soccer will become second nature. It is also ... The 10 Best Habits for Footballers: To become the best footballer you can be, and reach your ultimate potential on the pitch, focus on incorporating these habits into your daily routine. ... The way you make a difference on the game and the way you enjoy the game is being good with the ball at your feet. If you don't touch the ball outside of ... Your goal as a soccer player should be to become a more fascia-driven athlete, which all top athletes already are consciously or subconsciously. By improving the quality of your fascia, developing your athleticism, and applying many other tips on this list, you will also become more resistant to injury , allowing you to stay healthy on the ...
# Thought:I have found some tips and advice on becoming a good footballer.
# Thought: Now I can summarize the information to provide a concise answer.
# Action: Summarizer
# Action Input: "To become a good footballer, it takes years of hard work and an intensive routine. Here are some tips: 1. Practice every day and focus on your first touch and ball control. 2. Incorporate good habits into your daily routine. 3. Improve the quality of your fascia for better athleticism and injury resistance."
# Observation: Becoming a skilled footballer requires dedication and a structured routine. Some tips for aspiring players include practicing daily and prioritizing first touch and ball control, integrating positive habits into their daily routine, and enhancing their fascia for improved athletic performance and injury prevention.
# Thought:I now know the final answer.
# Final Answer: To become a good footballer, it takes years of hard work and an intensive routine. Some tips for aspiring players include practicing every day and focusing on first touch and ball control, incorporating positive habits into their daily routine, and improving the quality of their fascia for better athleticism and injury resistance.
#
# > Finished chain.
# {'input': 'Please tell me how to become a good footballer', 'output': 'To become a good footballer, it takes years of hard work and an intensive routine. Some tips for aspiring players include practicing every day and focusing on first touch and ball control, incorporating positive habits into their daily routine, and improving the quality of their fascia for better athleticism and injury resistance.'}

# %%
# !pip show langchain
# Out:
# Name: langchain
# Version: 0.3.14
# Summary: Building applications with LLMs through composability
# Home-page: https://github.com/langchain-ai/langchain
# Author:
# Author-email:
# License: MIT
# Location: C:\Users\amanr\anaconda3\Lib\site-packages
# Requires: aiohttp, langchain-core, langchain-text-splitters, langsmith, numpy, pydantic, PyYAML, requests, SQLAlchemy, tenacity
# Required-by: langchain-community
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\amanr\anaconda3\Lib\site-packages)

# %%
# !pip show openai
# Out:
# Name: openai
# Version: 1.59.6
# Summary: The official Python library for the openai API
# Home-page: https://github.com/openai/openai-python
# Author:
# Author-email: OpenAI <support@openai.com>
# License:
# Location: C:\Users\amanr\anaconda3\Lib\site-packages
# Requires: anyio, distro, httpx, jiter, pydantic, sniffio, tqdm, typing-extensions
# Required-by:
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\amanr\anaconda3\Lib\site-packages)
